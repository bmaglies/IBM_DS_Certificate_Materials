# %% [markdown]
# # First Major Jupyter Notebook

# %%
1+1
# Out:
# Waiting for a Spark session to start...
# Spark Initialization Done! ApplicationId = app-20190625204015-0000
# KERNEL_ID = f2a6c912-62c9-44ba-b4d6-76c3219877ea
# 2

# %%
x = "Mansfield"

# %%
display(x)
# Out:
# 'Mansfield'

# %%
print(x)
# Out:
# Mansfield

# %%
y = "Hellbrook"
z = "Adam's Apple"

# %%
print(y)
# Out:
# Hellbrook

# %%
print(z)
# Out:
# Adam's Apple

# %% [markdown]
# # Runs off the Chin
# ### Brought to you by Bob
# - Profanity
#     - Bathroom Chutes (Will not get you to Hellbrook)
# - Hour Glass
# - North Ridge
#
# #### _Don't worry, all roads lead to Hellbrook_

# %% [markdown]
# <img src="https://www.notneutral.com/pub/media/catalog/product/cache/e4d64343b1bc593f1c5348fe05efa4a6/l/i/lino_deathbeforedecaf_1080.jpg" alt="Death before decaf mug" title="Death Before Decaf"/>
