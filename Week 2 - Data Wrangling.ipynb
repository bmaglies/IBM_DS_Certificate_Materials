# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be performing data wrangling.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Identify duplicate values in the dataset.
#
# *   Remove duplicate values from the dataset.
#
# *   Identify missing values in the dataset.
#
# *   Impute the missing values in the dataset.
#
# *   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# In this section you will identify duplicate values in the dataset.

# %% [markdown]
# Find how many duplicate rows exist in the dataframe.

# %%
df.duplicated().sum()
# Out:
# 154

# %%
df['Respondent'].duplicated().sum()
# Out:
# 154

# %%
# your code goes here
df_ndv = df.drop_duplicates()
print(df_ndv.shape)
print(df.shape)
print(11552-11398, 'Duplicate rows removed')
# Out:
# (11398, 85)
# (11552, 85)
# 154 Duplicate rows removed

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
#your code here
df_ndv = df.drop_duplicates()
# Out:
# (11398, 85)
# (11552, 85)

# %% [markdown]
# Verify if duplicates were actually dropped.
# print(df_ndv.shape)
# print(df.shape)

# %%
# your code goes here
print(df_ndv.shape)
print(df.shape)
# Out:
# (11398, 85)
# (11552, 85)

# %% [markdown]
# ## Finding Missing values

# %% [markdown]
# Find the missing values for all columns.

# %%
# your code goes here
df_ndv.isnull().sum()
# Out:
# Respondent        0
# MainBranch        0
# Hobbyist          0
# OpenSourcer       0
# OpenSource       81
#                ...
# Sexuality       542
# Ethnicity       675
# Dependents      140
# SurveyLength     19
# SurveyEase       14
# Length: 85, dtype: int64

# %% [markdown]
# Find out how many rows are missing in the column 'WorkLoc'

# %%
# your code goes here
df_ndv['WorkLoc'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column WorkLoc.

# %%
# your code goes here
df_ndv['UndergradMajor'].unique()
# Out:
# array(['Computer science, computer engineering, or software engineering',
#        nan,
#        'Information systems, information technology, or system administration',
#        'Another engineering discipline (ex. civil, electrical, mechanical)',
#        'A business discipline (ex. accounting, finance, marketing)',
#        'Web development or web design', 'Mathematics or statistics',
#        'A social science (ex. anthropology, psychology, political science)',
#        'Fine arts or performing arts (ex. graphic design, music, studio art)',
#        'A natural science (ex. biology, chemistry, physics)',
#        'A humanities discipline (ex. literature, history, philosophy)',
#        'I never declared a major',
#        'A health science (ex. nursing, pharmacy, radiology)'],
#       dtype=object)

# %% [markdown]
# Identify the value that is most frequent (majority) in the WorkLoc column.

# %%
#make a note of the majority value here, for future reference
print("Office is top value")
# Out:
# Office is top value

# %% [markdown]
# Impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority.

# %%
# your code goes here

df_ndv['WorkLoc'] = df_ndv['WorkLoc'].fillna('Office')
# Out:
# /tmp/wsuser/ipykernel_155/589628530.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ndv['WorkLoc'] = df_ndv['WorkLoc'].fillna('Office')
# count      11398
# unique         3
# top       Office
# freq        6838
# Name: WorkLoc, dtype: object

# %% [markdown]
# After imputation there should ideally not be any empty rows in the WorkLoc column.

# %% [markdown]
# Verify if imputing was successful.

# %%
# your code goes here
print((df_ndv['WorkLoc'].isnull().sum()),'Nan Values')
df_ndv['WorkLoc'].describe()
# Out:
# 0 Nan Values
# count      11398
# unique         3
# top       Office
# freq        6838
# Name: WorkLoc, dtype: object

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section you will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %% [markdown]
# <hr>

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
# your code goes here
df_ndv['CompFreq'].unique()
# Out:
# array(['Yearly', 'Monthly', 'Weekly', nan], dtype=object)

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %% [markdown]
# Double click to see the **Hint**.
#
# <!--
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
#
# -->

# %%
df_ndv['CompFreq'].value_counts()
# Out:
# Yearly     6073
# Monthly    4788
# Weekly      331
# Name: CompFreq, dtype: int64

# %%
df_ndv['CompFreq'] = df_ndv['CompFreq'].fillna('Yearly')
df_ndv['CompTotal'] = df_ndv['CompTotal'].fillna(df_ndv['CompTotal'].median())
# Out:
# /tmp/wsuser/ipykernel_155/2166373751.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ndv['CompFreq'] = df_ndv['CompFreq'].fillna('Yearly')
# /tmp/wsuser/ipykernel_155/2166373751.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ndv['CompTotal'] = df_ndv['CompTotal'].fillna(df_ndv['CompTotal'].median())

# %%
df_ndv['CompFreq'].isnull().sum()
# Out:
# 0

# %%
# your code goes here
df_ndv['NormalizedAnnualCompensation'] = np.nan
annual=[]
def comp_norm():
    for x,y in zip(df_ndv['CompFreq'],df_ndv['CompTotal']):
        if x == "Monthly":
            annual.append(y*12)
        elif x == "Weekly":
            annual.append(y*52)
        else:
            annual.append(y)
comp_norm()

df_ndv['NormalizedAnnualCompensation']=annual
df_ndv['NormalizedAnnualCompensation'].head()
# Out:
# /tmp/wsuser/ipykernel_155/825236434.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ndv['NormalizedAnnualCompensation'] = np.nan
# /tmp/wsuser/ipykernel_155/825236434.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ndv['NormalizedAnnualCompensation']=annual
# 0     61000.0
# 1    138000.0
# 2     90000.0
# 3    348000.0
# 4     90000.0
# Name: NormalizedAnnualCompensation, dtype: float64

# %%
df_ndv['NormalizedAnnualCompensation'].median()
# Out:
# 103000.0

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
