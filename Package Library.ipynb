# %% [markdown]
# <h1 align="center"> Package Library </h1>
#
# <h3 align="center"> Created as a way to document and store imported packages' code that can be used for many projects</h3>

# %%
## Package set from NYC lab // Multiple of these used for Battle of Neighborhoods project. 

# Beautiful soup for scraping web pages
import requests
from bs4 import BeautifulSoup

# OG dataframe libraries
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Additional DF libraries
import json # library to handle JSON files
import csv # library to handle csv files
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

## Plotting/ Mapping installs and libraries. 
#!conda install -c conda-forge geopy --yes #Uncomment to install needed package for maps. Note this will not be used until 2nd half of project 
#from geopy.geocoders import Nominatim # convert an address into latitude and longitude values (Also used for 2nd half.)

#!conda install -c conda-forge folium=0.5.0 --yes # Also used for mapping in 2nd half of project. 
#import folium # map rendering library

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

print('Libraries imported.')
# Out:
# Libraries imported.
