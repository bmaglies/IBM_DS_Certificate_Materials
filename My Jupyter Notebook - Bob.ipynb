# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Bob M**
# Data Scientist

# %% [markdown]
# _I am interested in Data Science as I thoroughly enjoy analyzing problems and discovering solutions. I enjoy working on large data sets and have a passion for statistics. It is also a large growing field and I aspire to be ahead of the curve in this job market._

# %% [markdown]
# ### My code below is designed to solve a mathematical equation of 20 added to 20, producing the correct answer of 40.

# %%
20 + 20
# Out:
# 40

# %% [markdown]
# 1.  Numbered List
# 2.  Numbered List
# 3.  Numbered List
#
# __[Google](https://www.google.com/)__
#
#
# #### Image embedded below.
# <img src="https://upload.wikimedia.org/wikipedia/en/0/00/IBM_Watson_Logo_2017.png" />
